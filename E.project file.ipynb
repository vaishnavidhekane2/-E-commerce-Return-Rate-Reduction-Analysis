# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# pip install pandas sqlalchemy mysql-connector-python

# %%
# Create the engine 
import pandas as pd
from sqlalchemy import create_engine

# %%
import pandas as pd

df = pd.read_sql_query("C:\Users\VAIBHAV\Downloads\sqlre.sql")

# %%
# Connect MYSQL to Python
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+mysqlconnector://root:Vaishnav%4070666@localhost:3306/ecomm_returns"
)

df = pd.read_sql("SELECT * FROM ecomm_returns", engine)
df.head()

# %%
df['price_bucket'] = pd.cut(
    df['price'],
    bins=[0,5000,20000,50000],
    labels=['Low','Medium','High']
)

# %%
df_encoded = pd.get_dummies(
    df[['category','supplier','state','marketing_channel','price','returned']],
    drop_first=True
)

# %%
# Logistics Regreation
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = df_encoded.drop('returned', axis=1)
y = df_encoded['returned']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# %%
high_risk = df[df['return_probability'] >= 0.7]

high_risk.to_csv("high_risk_products.csv", index=False)
